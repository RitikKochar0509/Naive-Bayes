# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('../mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
le = LabelEncoder()
ds = df.apply(le.fit_transform)

# %%
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
data = ds.values

# %%
data
# Out:
# array([[1, 5, 2, ..., 2, 3, 5],
#        [0, 5, 2, ..., 3, 2, 1],
#        [0, 0, 2, ..., 3, 2, 3],
#        ...,
#        [0, 2, 2, ..., 0, 1, 2],
#        [1, 3, 3, ..., 7, 4, 2],
#        [0, 5, 2, ..., 4, 1, 2]])

# %%
data_y = data[:,0]
data_x = data[:,1:]

# %%
x_train,x_test,y_train,y_test = train_test_split(data_x,data_y,test_size = 0.2)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (6499, 22) (6499,) (1625, 22) (1625,)

# %%
np.unique(y_train,return_counts=True)
# Out:
# (array([0, 1]), array([3358, 3141], dtype=int64))

# %%
def prior_prob(y_train,label):
    total_examples = y_train.shape[0]
    class_examples = np.sum(y_train==label)
    
    return class_examples/float(total_examples)

# %%
a = np.array([0,5,5,1,1,1,1,1,0,0])

# %%
def cond_prob(x_train,y_train,feature_col,feature_val,label):
    x_filtered = x_train[y_train==label]
    numerator = np.sum(x_filtered[:,feature_col]==feature_val)
    
    denominator = np.sum(y_train==label)
    
    return numerator/float(denominator)

# %%
def predict(x_train,y_train,x_test):
    """xtest is a single testing point , with n features"""
    classes = np.unique(y_train)
    n_features = x_train.shape[1]
    post_prob = []
    
    for label in classes:
        likelihood = 1
        for f in range(n_features):
            cond = cond_prob(x_train,y_train,f,x_test[f],label)
            likelihood *= cond
        prior = prior_prob(y_train,label)
        
        post = likelihood*prior
        
        post_prob.append(post)
    pred = np.argmax(post_prob)
    
    return pred

# %%
output = predict(x_train,y_train,x_test[100])
print(output)
# Out:
# 0

# %%
print(y_test[100])
# Out:
# 0

# %%
def score(x_train,y_train,x_test,y_test):
    
    pred =[]
    for i in range(x_test.shape[0]):
        pred_label = predict(x_train,y_train,x_test[i])
        pred.append(pred_label)
    pred = np.array(pred)
    accurcy = np.sum(pred==y_test)/y_test.shape[0]
    return accurcy

# %%
print(score(x_train,y_train,x_test,y_test)*100)
# Out:
# 99.81538461538462
